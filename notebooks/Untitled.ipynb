# %%
import requests

# %%
api = 'http://dev.moyuniver.ru/api/php/v03/'

appid=306
appsgn='d8629af695839ba5481757a519e57fb1'

api_end = '&appid={}&appsgn={}&appcode={}&os=&ver=&width=&height='.format(appid, appsgn,'vkcommunity')

# %%
query = 'api_questions.php?did=21&page=1&q=20&memberid=28665485147fa7133b44cb'

full_query = api+query+api_end
print full_query

resp = requests.post(full_query)

print resp

print resp.text.encode('utf8')


# print (json.dumps(result, indent=4, sort_keys=True, ensure_ascii=False))
# Out:
# http://dev.moyuniver.ru/api/php/v03/api_questions.php?did=21&page=1&q=20&memberid=28665485147fa7133b44cb&appid=306&appsgn=d8629af695839ba5481757a519e57fb1&appcode=vkcommunity&os=&ver=&width=&height=
# <Response [200]>
# 12058{#}Ð.Ð ÑÐ±Ð»ÐµÐ², ÐÐµÑÑÐ¾Ñ, ÐÐ°Ð½Ð¸Ð¸Ð» ÐÐ°ÑÐ¾ÑÐ½Ð¸Ðº ÑÑÐ¾:{#}0{#}
# 12103{#}ÐÐ±ÑÐ¾Ð»ÑÑÐ½Ð°Ñ Ð¼Ð¾Ð½Ð°ÑÑÐ¸Ñ ÑÐ°ÑÐ°ÐºÑÐµÑÐ¸Ð·ÑÐµÑÑÑ ÑÐ»ÐµÐ´ÑÑÑÐ¸Ð¼Ð¸ Ð¿ÑÐ¸Ð·Ð½Ð°ÐºÐ°Ð¼Ð¸ (ÑÐºÐ°Ð·Ð°ÑÑ Ð½ÐµÐ²ÐµÑÐ½ÑÐ¹ Ð¾ÑÐ²ÐµÑ):{#}1{#}
# 12069{#}ÐÐ¸ÑÐ²Ð° Ð½Ð° ÑÐµÐºÐµ ÐÐ°Ð»ÐºÐµ, Ð³Ð´Ðµ ÑÑÑÑÐºÐ¸Ðµ ÐºÐ½ÑÐ·ÑÑ Ð²Ð¿ÐµÑÐ²ÑÐµ Ð²ÑÑÑÐµÑÐ¸Ð»Ð¸ÑÑ Ñ Ð¼Ð¾Ð½Ð³Ð¾Ð»Ð¾-ÑÐ°ÑÐ°ÑÐ°Ð¼Ð¸, Ð¿ÑÐ¾Ð¸Ð·Ð¾ÑÐ»Ð° Ð² (Ð³Ð¾Ð´Ñ):{#}1{#}
# 12086{#}ÐÐ¾ÑÐ¸Ñ ÐÐ¾Ð´ÑÐ½Ð¾Ð², ÐÐ°ÑÐ¸Ð»Ð¸Ð¹ Ð¨ÑÐ¹ÑÐºÐ¸Ð¹ ÑÑÐ¾:{#}1{#}
# 12082{#}Ð ÐÐ¾Ð²Ð³Ð¾ÑÐ¾Ð´ÑÐºÐ¾Ð¹ ÑÐµÑÐ¿ÑÐ±Ð»Ð¸ÐºÐµ Ð·Ð°ÐºÐ¾Ð½Ð¾Ð´Ð°ÑÐµÐ»ÑÐ½Ð°Ñ Ð²Ð»Ð°ÑÑÑ Ð¿ÑÐ¸Ð½Ð°Ð´Ð»ÐµÐ¶Ð°Ð»Ð°:{#}1{#}
# 12059{#}Ð Ð¿ÐµÑÐ¸Ð¾Ð´ ÐÐ¸ÐµÐ²ÑÐºÐ¾Ð¹ Ð ÑÑÐ¸ Ð½Ð°ÑÐ°Ð»Ð° ÑÐºÐ»Ð°Ð´ÑÐ²Ð°ÑÑÑÑ:{#}0{#}
# ...
